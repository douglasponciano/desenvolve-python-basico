# %%
print("Meu Primeiro Codigo")
# Out:
# Meu Primeiro Codigo

# %%
x =10
y =5
print (x+1)
print (y-2)
print (y*x)
print (x/y)
# Out:
# 11
# 3
# 50
# 2.0

# %%
print ("ola)
# Out:
#   Cell In[5], line 1
#     print ("ola)
#            ^
# SyntaxError: unterminated string literal (detected at line 1)
